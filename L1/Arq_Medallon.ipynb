# %%
# Databricks notebook source
# MAGIC %md
# MAGIC # Cuaderno 1: Preparación de Datos
# MAGIC Ejecuta: 01_bronze_to_silver, 02_silver_to_gold, 03_rfm_analysis

# COMMAND ----------

# Ejecutar 01_bronze_to_silver
try:
    print("▶️  Ejecutando 01_ingest_bronze...")
    dbutils.notebook.run("01_ingest_bronze", timeout_seconds=1800)
    print("✅ Completado\n")
except Exception as e:
    print(f"❌ ERROR en 01_ingest_bronze: {e}")
    dbutils.notebook.exit("FAILED: 01_ingest_bronze")

# COMMAND ----------

# Ejecutar 02_silver_to_gold
try:
    print("▶️  Ejecutando 02_transform_silver...")
    dbutils.notebook.run("02_transform_silver", timeout_seconds=1800)
    print("✅ Completado\n")
except Exception as e:
    print(f"❌ ERROR en 02_transform_silver: {e}")
    dbutils.notebook.exit("FAILED: 02_transform_silver")

# COMMAND ----------

# Ejecutar 03_rfm_analysis
try:
    print("▶️  Ejecutando 03_rfm_and_filter_3...")
    dbutils.notebook.run("03_rfm_and_filter_3", timeout_seconds=1800)
    print("✅ Completado\n")
except Exception as e:
    print(f"❌ ERROR en 03_rfm_and_filter_3: {e}")
    dbutils.notebook.exit("FAILED: 03_rfm_and_filter_3")

# COMMAND ----------

print("🎉 Grupo 1 completado exitosamente")
dbutils.notebook.exit("SUCCESS")
