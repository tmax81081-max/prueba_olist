# %%
# Databricks notebook source
# MAGIC %md
# MAGIC # Cuaderno 4: Evaluación e Inferencia
# MAGIC Ejecuta: 09_evaluate_test, 10_inference_pipeline_production, 11_predict_premium_customers, convertir_a_tablas

# COMMAND ----------

# Ejecutar 09_evaluate_test
try:
    print("▶️  Ejecutando 09_evaluate_test...")
    dbutils.notebook.run("09_evaluate_test", timeout_seconds=1800)
    print("✅ Completado\n")
except Exception as e:
    print(f"❌ ERROR en 09_evaluate_test: {e}")
    dbutils.notebook.exit("FAILED: 09_evaluate_test")

# COMMAND ----------

# Ejecutar 10_inference_pipeline_production
try:
    print("▶️  Ejecutando 10_inference_pipeline_production...")
    dbutils.notebook.run("10_inference_pipeline_production", timeout_seconds=3600)  # 60 min
    print("✅ Completado\n")
except Exception as e:
    print(f"❌ ERROR en 10_inference_pipeline_production: {e}")
    dbutils.notebook.exit("FAILED: 10_inference_pipeline_production")

# COMMAND ----------

# Ejecutar 11_predict_premium_customers
try:
    print("▶️  Ejecutando 11_predict_premium_customers...")
    dbutils.notebook.run("11_predict_premium_customers", timeout_seconds=3600)  # 60 min
    print("✅ Completado\n")
except Exception as e:
    print(f"❌ ERROR en 11_predict_premium_customers: {e}")
    dbutils.notebook.exit("FAILED: 11_predict_premium_customers")

# COMMAND ----------

# Ejecutar convertir_a_tablas
try:
    print("▶️  Ejecutando Convertir...")
    dbutils.notebook.run("convertir_Convertira_tablas", timeout_seconds=1800)
    print("✅ Completado\n")
except Exception as e:
    print(f"❌ ERROR en Convertir: {e}")
    dbutils.notebook.exit("FAILED: Convertir")

# COMMAND ----------

print("🎉 Grupo 4 completado exitosamente")
dbutils.notebook.exit("SUCCESS")
