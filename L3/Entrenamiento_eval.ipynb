# %%
# Databricks notebook source
# MAGIC %md
# MAGIC # Cuaderno 3: Feature Engineering y ML
# MAGIC Ejecuta: 05_feature_engineering, 06_pca_transformation, 07_train_test_split, 08_train_models

# COMMAND ----------

# Ejecutar 05_feature_engineering
try:
    print("▶️  Ejecutando 05_generate_gold_features...")
    dbutils.notebook.run("05_generate_gold_features", timeout_seconds=1800)
    print("✅ Completado\n")
except Exception as e:
    print(f"❌ ERROR en 05_generate_gold_features: {e}")
    dbutils.notebook.exit("FAILED: 05_generate_gold_features")

# COMMAND ----------

# Ejecutar 06_pca_transformation
try:
    print("▶️  Ejecutando 06_feature_correlation_pca_reduction_PROD...")
    dbutils.notebook.run("06_feature_correlation_pca_reduction_PROD", timeout_seconds=1800)
    print("✅ Completado\n")
except Exception as e:
    print(f"❌ ERROR en 06_feature_correlation_pca_reduction_PROD: {e}")
    dbutils.notebook.exit("FAILED: 06_feature_correlation_pca_reduction_PROD")

# COMMAND ----------

# Ejecutar 07_train_test_split
try:
    print("▶️  Ejecutando 07_train_val_test_split...")
    dbutils.notebook.run("07_train_val_test_split", timeout_seconds=1800)
    print("✅ Completado\n")
except Exception as e:
    print(f"❌ ERROR en 07_train_val_test_split: {e}")
    dbutils.notebook.exit("FAILED: 07_train_val_test_split")

# COMMAND ----------

# Ejecutar 08_train_models
try:
    print("▶️  Ejecutando 08_train_models...")
    dbutils.notebook.run("08_train_models", timeout_seconds=3600)  # 60 min
    print("✅ Completado\n")
except Exception as e:
    print(f"❌ ERROR en 08_train_models: {e}")
    dbutils.notebook.exit("FAILED: 08_train_models")

# COMMAND ----------

print("🎉 Grupo 3 completado exitosamente")
dbutils.notebook.exit("SUCCESS")
