# %%
# Databricks notebook source
# MAGIC %md
# MAGIC # Cuaderno 2: Segmentación K-Means
# MAGIC Ejecuta: 04_kmeans_segmentation

# COMMAND ----------


# Ejecutar 04_kmeans_segmentation
try:
    print("▶️  Ejecutando 04_kmeans_segmentation...")
    dbutils.notebook.run("04_kmeans_segmentation", timeout_seconds=1800)
    print("✅ Completado\n")
except Exception as e:
    print(f"❌ ERROR en 04_kmeans_segmentation: {e}")
    dbutils.notebook.exit("FAILED: 04_kmeans_segmentation")

# COMMAND ----------

print("🎉 Grupo 2 completado exitosamente")
dbutils.notebook.exit("SUCCESS")
